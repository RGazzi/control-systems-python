# %%
# !pip install control
import matplotlib.pyplot as plt
import numpy as np
import control as ctl
from control import TransferFunction
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.6/549.6 kB 6.8 MB/s eta 0:00:00
# ...

# %%
m=1
b=2
k=4

num = [1]
den = [m, b, k]

plant_tf = ctl.TransferFunction(num, den)
plant_tf

# Diagrama de Bode
plt.figure()
plt.title("bode plot")
ctl.bode_plot(plant_tf, dB=True, Hz=True, deg=True)
plt.show()

# %%
# !pip install control

import matplotlib.pyplot as plt
import numpy as np
import control as ctl
from control import TransferFunction

m=1
b=2
k=4

num = [1]
den = [m, b, k]

plant_tf = ctl.TransferFunction(num, den)
plant_tf

#Diag. Nyquist
plt.figure()
plt.title("Nyquist Plot")
ctl.nyquist_plot(plant_tf)
plt.grid()
plt.show()

# %%
# !pip install control

import matplotlib.pyplot as plt
import numpy as np
import control as ctl
from control import TransferFunction

m=1
b=2
k=4

num = [1]
den = [m, b, k]

plant_tf = ctl.TransferFunction(num, den)
plant_tf

#Diag. Nyquist
plt.figure()
plt.title("Nichols Plot")
ctl.nichols_plot(plant_tf)
plt.show()
