# %%
# !pip install control
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.6/549.6 kB 6.1 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import control as ctl
from control import (TransferFunction)

#parametros
m = 1 #massa
b = 5 #coef. amortecimento
k = 4 #coef. elasticidade

y0 = [0.0, 0.0] #condições de posição e velocidade nulas
t = np.linspace(0, 20,  1001)
u = np.ones(1001) #entrada degrau unitário -> u(t)=f(t)

#função transferência
plant_tf = TransferFunction(1, [m,b,k]) #1 = numerador e [m,b,k] = denominador
print ('plant_ft=/n', plant_tf)

#resposta forçada
xout, yout = ctl.forced_response(plant_tf, U=u, T=t)  #calculo da resposta forçada
plt.plot(t, yout, 'k', linewidth=1.5, label='posição')
plt.legend(loc='best', shadow = True, framealpha=1)
plt.grid(alpha=0.1)
plt.xlabel('t')
plt.show()
# Out:
# plant_ft=/n <TransferFunction>: sys[0]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#       1
# -------------
# s^2 + 5 s + 4
